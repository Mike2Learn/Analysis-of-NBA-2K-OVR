# %%
#!pip install openpyxl

# %%
#!pip install xlrd

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import openpyxl
import xlrd

# %%
path = "C:/Users/74279/PycharmProjects/NBA2K-Ratings/Data/"
path
# Out:
# 'C:/Users/74279/PycharmProjects/NBA2K-Ratings/Data/'

# %%
#Read in 2021-2022 NBA Player Stats
stats_2122 = pd.read_excel(path+"2021-2022 NBA Player Stats.xlsx")
stats_2122.columns = stats_2122.iloc[0]
stats_2122 = stats_2122.iloc[1:,1:]

#Read in NBA 2k23 Ratings
ratings_23 = pd.read_excel(path+"2k23 ratings.xlsx")

#Merge these two dataframes
stats_2122 = stats_2122.merge(ratings_23,left_on="FULL NAME",right_on="FULL NAME")

# %%
stats_2122
# Out:
#                     FULL NAME TEAM  POS    AGE  GP   MPG  \
# 0            Precious Achiuwa  Tor    F  22.56  73  23.6
# 1                Steven Adams  Mem    C  28.73  76  26.3
# 2                 Bam Adebayo  Mia  C-F  24.73  56  32.6
# 3    Nickeil Alexander-Walker  Nor    G  23.61  50  26.3
# 4    Nickeil Alexander-Walker  Uta    G  23.61  15   9.9
# ..                        ...  ...  ...    ...  ..   ...
# 426            Thaddeus Young  San    F   33.8  26  14.2
# 427            Thaddeus Young  Tor    F   33.8  26  18.3
# 428                Trae Young  Atl    G  23.56  76  34.9
# 429            Omer Yurtseven  Mia    C  23.81  56  12.6
# 430               Ivica Zubac  Lac    C  25.07  76  24.4
#
#     MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# 0                                                 49.2
# 1                                                 54.8
# 2                                                 67.9
# ...

# %%
#Read in 2020-2021 NBA Player Stats
stats_2021 = pd.read_excel(path+"2020-2021 NBA Player Stats.xlsx")
stats_2021.columns = stats_2021.iloc[0]
stats_2021 = stats_2021.iloc[1:,1:]

#Read in NBA 2k22 Ratings
ratings_22 = pd.read_excel(path+"2k22 ratings.xlsx")

#Merge these two dataframes
stats_2021 = stats_2021.merge(ratings_22,left_on="FULL NAME",right_on="FULL NAME")

# %%
stats_2021
# Out:
#              FULL NAME TEAM  POS    AGE  GP   MPG  \
# 0     Precious Achiuwa  Mia    F  21.66  61  12.1
# 1         Steven Adams  Nor    C  27.83  58  27.7
# 2          Bam Adebayo  Mia  C-F  23.83  64  33.5
# 3    LaMarcus Aldridge  San  C-F  35.83  21  25.9
# 4    LaMarcus Aldridge  Bro  C-F  35.83   5    26
# ..                 ...  ...  ...    ...  ..   ...
# 416       Delon Wright  Sac    G  29.06  27  25.8
# 417     Thaddeus Young  Chi    F   32.9  68  24.3
# 418         Trae Young  Atl    G  22.66  63  33.7
# 419        Cody Zeller  Cha  F-C  28.61  48  20.9
# 420        Ivica Zubac  Lac    C  24.16  72  22.3
#
#     MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# 0                                                 25.2
# 1                                                 57.6
# 2                                                 69.7
# 3                                                   54
# ...

# %%
#Read in 2021-2022 NBA Player Stats
stats_1920 = pd.read_excel(path+"2019-2020 NBA Player Stats.xlsx")
stats_1920.columns = stats_1920.iloc[0]
stats_1920 = stats_1920.iloc[1:,1:]

#Read in NBA 2k21 Ratings
ratings_21 = pd.read_excel(path+"2k21 ratings.xlsx")
#Merge these two dataframes
stats_1920 = stats_1920.merge(ratings_21,left_on="FULL NAME",right_on="FULL NAME")

# %%
stats_1920
# Out:
#                     FULL NAME TEAM  POS    AGE  GP   MPG  \
# 0                Steven Adams  Okc    C  27.07  63  26.7
# 1                 Bam Adebayo  Mia  C-F  23.08  72  33.6
# 2           LaMarcus Aldridge  San  F-C  35.07  53  33.1
# 3              Kyle Alexander  Mia  F-C  23.81   2   6.7
# 4    Nickeil Alexander-Walker  Nor    G  21.95  47  12.6
# ..                        ...  ...  ...    ...  ..   ...
# 531                Trae Young  Atl    G   21.9  60  35.3
# 532               Cody Zeller  Cha    C  27.86  58  23.1
# 533              Tyler Zeller  San  F-C  30.58   2     2
# 534                Ante Zizic  Cle    C  23.61  22    10
# 535               Ivica Zubac  Lac    C  23.41  72  18.4
#
#     MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# 0                                                 55.6
# 1                                                 69.9
# 2                                                 68.9
# ...

# %%
#Read in 2018-2019 NBA Player Stats
stats_1819 = pd.read_excel(path+"2018-2019 NBA Player Stats.xlsx")
stats_1819.columns = stats_1819.iloc[0]
stats_1819 = stats_1819.iloc[1:,1:]

#Read in NBA 2k20 Ratings
ratings_20 = pd.read_excel(path+"2k20 ratings.xlsx")
#Merge these two dataframes
stats_1819 = stats_1819.merge(ratings_20,left_on="FULL NAME",right_on="FULL NAME")

# %%
stats_1819
# Out:
#              FULL NAME TEAM  POS    AGE  GP   MPG  \
# 0         Steven Adams  Okc    C  25.73  80  33.4
# 1          Bam Adebayo  Mia  C-F  21.73  82  23.3
# 2    LaMarcus Aldridge  San    F  33.73  81  33.2
# 3        Grayson Allen  Uta    G  23.51  38    11
# 4        Jarrett Allen  Bro    C  20.97  80  26.2
# ..                 ...  ...  ...    ...  ..   ...
# 392         Trae Young  Atl    G  20.56  81  30.9
# 393        Cody Zeller  Cha  F-C  26.51  49  25.4
# 394         Ante Zizic  Cle    C  22.27  59  18.3
# 395        Ivica Zubac  Lal    C  22.07  33  15.6
# 396        Ivica Zubac  Lac    C  22.07  26  20.1
#
#     MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# 0                                                 69.5
# 1                                                 48.6
# 2                                                 69.1
# 3                                                 22.8
# ...

# %%
#Read in 2017-2018 NBA Player Stats
stats_1718 = pd.read_excel(path+"2017-2018 NBA Player Stats.xlsx")
stats_1718.columns = stats_1718.iloc[0]
stats_1718 = stats_1718.iloc[1:,1:]

#Read in NBA 2k20 Ratings
ratings_19 = pd.read_excel(path+"2k19 ratings.xlsx")
#Merge these two dataframes
stats_1718 = stats_1718.merge(ratings_19,left_on="FULL NAME",right_on="FULL NAME")
#Uniform column names
stats_1718.columns = stats_1819.columns

# %%
stats_1718
# Out:
#          FULL NAME TEAM POS AGE  GP   MPG  \
# 0     Aaron Gordon  Orl  SF  22  58  32.9
# 1      Abdel Nader  Bos  SF  24  48  10.9
# 2       Al Horford  Bos   C  31  72  31.6
# 3     Al Jefferson  Ind   C  33  36  13.4
# 4    Alan Williams  Pho  PF  25   5  14.1
# ..             ...  ...  ..  ..  ..   ...
# 441   Zach Collins  Por   C  20  66  15.8
# 442    Zach LaVine  Chi  SG  22  24  27.3
# 443  Zach Randolph  Sac  PF  36  59  25.6
# 444  Zaza Pachulia  Gol   C  33  69  14.1
# 445        Zhou Qi  Hou  PF  22  18   6.9
#
#     MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# 0                                                 68.6
# 1                                                 22.6
# 2                                                 65.9
# 3                                                   28
# 4                                                 29.3
# ..                                                 ...
# ...

# %%
#Combine these stats and drop columns with nan
frames = [stats_2122,stats_2021,stats_1920,stats_1819,stats_1718]
stats_1722 = pd.concat(frames)
stats_1722 = stats_1722.dropna(axis=1)

# %%
#The column names are too prolix, so let's make it shorter
stats_1722.rename(columns=lambda x: x[:3], inplace=True)
stats_1722.rename(columns={"FUL":"FULL NAME","TEA":"TEAM","RAT":"RATING"},inplace=True)
#Drop column 'TOP'
stats_1722 = stats_1722.drop("TOP",axis=1)

# %%
stats_1722[stats_1722["FULL NAME"]=="James Harden"]
# Out:
#         FULL NAME TEAM POS    AGE  GP   MPG   MIN   USG  FTA    FT%  ...  \
# 156  James Harden  Bro   G  32.63  44    37  77.1  28.3  350  0.869  ...
# 157  James Harden  Phi   G  32.63  21  37.7  78.6  24.9  186  0.892  ...
# 164  James Harden  Hou   G  31.72   8  36.3  75.5  28.7   60  0.883  ...
# 165  James Harden  Bro   G  31.72  36  36.6  76.3  28.4  263  0.856  ...
# 212  James Harden  Hou   G  30.97  68  36.5  76.1  36.2  800  0.865  ...
# 150  James Harden  Hou   G  29.63  78  36.8  76.6  40.5  858  0.879  ...
# 194  James Harden  Hou  PG     28  72  35.4  73.8    36  727  0.858  ...
#
#        3P%   PPG  RPG   TRB   APG   AST   SPG   BPG   VIV RATING
# 156  0.332  22.5    8  11.7  10.2  39.7  1.27   0.7  13.2     89
# 157  0.326    21    7  10.4  10.5  41.4  1.29  0.24  12.3     89
# 164  0.347  24.8  5.1   7.5  10.4  46.9  0.88  0.75  12.1     94
# 165  0.366  24.6  8.6  12.9  10.9  43.8  1.28  0.75  14.4     94
# ...

# %%
#Read in 2016-2017 NBA Player Stats
stats_1617 = pd.read_excel(path+"2016-2017 NBA Player Stats.xlsx")
stats_1617.columns = stats_1617.iloc[0]
stats_1617 = stats_1617.iloc[1:,1:]

#Read in NBA 2k18 Ratings
ratings_18 = pd.read_excel(path+"2k18 ratings.xlsx")
#Merge these two dataframes
stats_1617 = stats_1617.merge(ratings_18,left_on="FULL NAME",right_on="FULL NAME")
#Add and drop some column
stats_1617 = stats_1617.drop('TOr',axis=1)
stats_1617 = stats_1617.drop('TS%',axis=1)
#Uniform column names
stats_1617.columns = stats_1722.columns

# %%
stats_1617[stats_1617["FULL NAME"]=="James Harden"]
# Out:
#         FULL NAME TEAM POS AGE  GP   MPG   MIN   USG  FTA    FT%  ...    3P%  \
# 163  James Harden  Hou  PG  27  81  36.4  75.8  34.3  881  0.847  ...  0.347
#
#       PPG  RPG   TRB   APG   AST   SPG   BPG   VIV RATING
# 163  29.1  8.1  12.2  11.2  50.7  1.49  0.47  15.2     95
#
# [1 rows x 23 columns]

# %%
#Read in 2015-2016 NBA Player Stats
stats_1516 = pd.read_excel(path+"2015-2016 NBA Player Stats.xlsx")
stats_1516.columns = stats_1516.iloc[0]
stats_1516 = stats_1516.iloc[1:,1:]

#Read in NBA 2k17 Ratings
ratings_17 = pd.read_excel(path+"2k17 ratings.xlsx")
#Merge these two dataframes
stats_1516 = stats_1516.merge(ratings_17,left_on="FULL NAME",right_on="FULL NAME")
#Add and drop some column
stats_1516 = stats_1516.drop('TOr',axis=1)
stats_1516 = stats_1516.drop('TS%',axis=1)
#Uniform column names
stats_1516.columns = stats_1722.columns

# %%
stats_1516[stats_1516["FULL NAME"]=="James Harden"]
# Out:
#         FULL NAME TEAM POS AGE  GP   MPG   MIN   USG  FTA   FT%  ...   3P%  \
# 143  James Harden  Hou  SG  26  82  38.1  79.4  32.5  837  0.86  ...  0.36
#
#     PPG  RPG  TRB  APG   AST   SPG   BPG   VIV RATING
# 143  29  6.1  8.9  7.5  35.4  1.68  0.62  11.5     90
#
# [1 rows x 23 columns]

# %%
stats_1522 = pd.concat([stats_1722,stats_1617,stats_1516])
stats_1522 = stats_1522.dropna(axis=1)

# %%
stats_1522
# Out:
#                     FULL NAME TEAM  POS    AGE  GP   MPG   MIN   USG  FTA  \
# 0            Precious Achiuwa  Tor    F  22.56  73  23.6  49.2  18.5  131
# 1                Steven Adams  Mem    C  28.73  76  26.3  54.8    12  199
# 2                 Bam Adebayo  Mia  C-F  24.73  56  32.6  67.9    25  340
# 3    Nickeil Alexander-Walker  Nor    G  23.61  50  26.3  54.9  24.8   97
# 4    Nickeil Alexander-Walker  Uta    G  23.61  15   9.9  20.7  17.9   12
# ..                        ...  ...  ...    ...  ..   ...   ...   ...  ...
# 376       Willie Cauley-Stein  Sac    C     22  66  21.4  44.6  13.2  125
# 377               Willie Reed  Bro   PF     25  39  10.9  22.7  18.1   55
# 378               Zach LaVine  Min   PG     20  82    28  58.3  23.5  203
# 379             Zach Randolph  Mem   PF     34  68  29.7  61.8  24.6  216
# 380             Zaza Pachulia  Dal    C     31  76  26.4  54.9  16.2  276
#
#        FT%  ...    3P%   PPG   RPG   TRB  APG   AST   SPG   BPG   VIV RATING
# ...

# %%
stats_1522[stats_1522["FULL NAME"]=="James Harden"]
# Out:
#         FULL NAME TEAM POS    AGE  GP   MPG   MIN   USG  FTA    FT%  ...  \
# 156  James Harden  Bro   G  32.63  44    37  77.1  28.3  350  0.869  ...
# 157  James Harden  Phi   G  32.63  21  37.7  78.6  24.9  186  0.892  ...
# 164  James Harden  Hou   G  31.72   8  36.3  75.5  28.7   60  0.883  ...
# 165  James Harden  Bro   G  31.72  36  36.6  76.3  28.4  263  0.856  ...
# 212  James Harden  Hou   G  30.97  68  36.5  76.1  36.2  800  0.865  ...
# 150  James Harden  Hou   G  29.63  78  36.8  76.6  40.5  858  0.879  ...
# 194  James Harden  Hou  PG     28  72  35.4  73.8    36  727  0.858  ...
# 163  James Harden  Hou  PG     27  81  36.4  75.8  34.3  881  0.847  ...
# 143  James Harden  Hou  SG     26  82  38.1  79.4  32.5  837   0.86  ...
#
#        3P%   PPG  RPG   TRB   APG   AST   SPG   BPG   VIV RATING
# 156  0.332  22.5    8  11.7  10.2  39.7  1.27   0.7  13.2     89
# 157  0.326    21    7  10.4  10.5  41.4  1.29  0.24  12.3     89
# ...

# %%
stats_1522.to_csv(path+"2015-2022 NBA Player Stats.csv")
